# %% [markdown]
# # Задание 1
#
# Загрузите данные по вариантам в ноутбук.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Вариант 2.xlsx', skiprows=2, skipfooter=1)
df
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
#
#       Минимальный балл
# 0                   27
# 1                   27
# 2                   27
# 3                   27
# 4                   27
# ...                ...
# 2351                27
# 2352                27
# 2353                27
# 2354                27
# 2355                27
#
# [2356 rows x 11 columns]

# %% [markdown]
# # Задание 2
#
# Сделайте описательную статистику полученных данных.

# %%
df.info
# Out:
# <bound method DataFrame.info of          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
#
#       Минимальный балл
# 0                   27
# 1                   27
# 2                   27
# 3                   27
# 4                   27
# ...                ...
# 2351                27
# 2352                27
# 2353                27
# 2354                27
# 2355                27
#
# [2356 rows x 11 columns]>

# %%
df.describe()
# Out:
#                  №      № школы  Номер варианта  Устная часть  Первичный балл  \
# count  2356.000000  2356.000000     2356.000000           0.0     2356.000000
# mean   1178.500000   132.005518      338.273769           NaN       10.123939
# std     680.262939     5.037984       53.660878           NaN        3.820484
# min       1.000000   121.000000      101.000000           NaN        1.000000
# 25%     589.750000   127.000000      339.000000           NaN        7.000000
# 50%    1178.500000   135.000000      342.500000           NaN       10.000000
# 75%    1767.250000   136.000000      346.000000           NaN       13.000000
# max    2356.000000   137.000000      506.000000           NaN       27.000000
#
#               Балл  Минимальный балл
# count  2356.000000            2356.0
# mean     49.255093              27.0
# std      17.880420               0.0
# min       5.000000              27.0
# 25%      33.000000              27.0
# 50%      50.000000              27.0
# 75%      68.000000              27.0
# max      96.000000              27.0

# %% [markdown]
# # Задание 3
#
# Найдите процент учащихся, выполнивших работу ниже среднего.

# %%
mean = df['Балл'].mean()
mean
# Out:
# 49.25509337860781

# %%
df_underav = df[df['Балл'] < mean]
df_underav
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 1126  1127      137   11Б   Ж             338              ++++-+--++++
# 1127  1128      137   11А   М             338              -+++++--+++-
# 1128  1129      137    11   М             342              ++++++--+++-
# 1129  1130      137    11   М             347              +++++++-++--
# 1130  1131      137    11   Ж             338              ++++++-++-+-
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 1126  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               9    45
# 1127  1(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               9    45
# 1128  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               9    45
# 1129  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               9    45
# 1130  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               9    45
#
#       Минимальный балл
# 0                   27
# 1                   27
# 2                   27
# 3                   27
# 4                   27
# ...                ...
# 1126                27
# 1127                27
# 1128                27
# 1129                27
# 1130                27
#
# [1131 rows x 11 columns]

# %%
percentage_underav = df_underav.shape[0] / df.shape[0] * 100
percentage_underav
# Out:
# 48.00509337860781

# %% [markdown]
# # Задание 4
#
# Найти процент учащихся не сдавших экзамен.

# %%
min = df['Минимальный балл'].min()
min
# Out:
# 27

# %%
df_undermin = df[df['Балл'] < min]
df_undermin
# Out:
#        №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0      1      124    11   Ж             341              ------+-----
# 1      2      128    11   Ж             345              -+----------
# 2      3      132    11   Ж             340              -+----------
# 3      4      134    11   Ж             339              -+----------
# 4      5      136    11   Ж             348              --------+---
# ..   ...      ...   ...  ..             ...                       ...
# 212  213      136   12В   Ж             345              ++++----+---
# 213  214      136   12А   М             342              ++-+---++---
# 214  215      136   12Б   М             337              --++--+-++--
# 215  216      136    11   М             345              +--+-+--++--
# 216  217      137    11   Ж             346              +--+++--+---
#
#     Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0    0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1    0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2    0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3    0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4    0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ..                            ...           ...             ...   ...
# 212  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               5    23
# 213  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               5    23
# 214  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               5    23
# 215  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               5    23
# 216  0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               5    23
#
#      Минимальный балл
# 0                  27
# 1                  27
# 2                  27
# 3                  27
# 4                  27
# ..                ...
# 212                27
# 213                27
# 214                27
# 215                27
# 216                27
#
# [217 rows x 11 columns]

# %%
percentage_undermin = df_undermin.shape[0] / df.shape[0] * 100
percentage_undermin
# Out:
# 9.210526315789473

# %% [markdown]
# # Задание 5
#
# Постройте круговую диаграмму, показывающую распределение сдавших и не сдавших экзамен.

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

data = [percentage_undermin, 100-percentage_undermin]

labels = ['Fail', 'Pass']

plt.figure(figsize=(4, 4))
plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Распределение сдавших и не сдавших экзамен')
plt.show()

# %% [markdown]
# # Задание 6
#
# Постройте ядерную оценку плотности распределению баллов за экзамен.

# %%
import seaborn

# %%
seaborn.kdeplot(df['Балл'], fill = True, color = 'grey')
# Out:
# <Axes: xlabel='Балл', ylabel='Density'>

# %% [markdown]
# # Задание 7
#
# Найдите процентное соотношение учащихся, сдавших экзамен на «отлично», «хорошо», «удовлетворительно», «неудовлетворительно».

# %%
def replace_func(x):
  if x < 63:
    return 2
  elif x >= 63 and x < 77:
    return 3
  elif x >= 77 and x < 91:
    return 4
  else:
    return 5

# %%
df['Балл 5'] = df.loc[:,'Балл']
df
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
#
#       Минимальный балл  Балл 5
# 0                   27       5
# 1                   27       5
# 2                   27       5
# 3                   27       5
# 4                   27       5
# ...                ...     ...
# 2351                27      92
# 2352                27      92
# 2353                27      96
# 2354                27      96
# 2355                27      96
#
# [2356 rows x 12 columns]

# %%
df['Балл 5'] = df['Балл 5'].apply(replace_func)
df
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
#
#       Минимальный балл  Балл 5
# 0                   27       2
# 1                   27       2
# 2                   27       2
# 3                   27       2
# 4                   27       2
# ...                ...     ...
# 2351                27       5
# 2352                27       5
# 2353                27       5
# 2354                27       5
# 2355                27       5
#
# [2356 rows x 12 columns]

# %%
df.groupby(['Балл 5']).agg({'Балл 5': 'count'})
# Out:
#         Балл 5
# Балл 5
# 2         1753
# 3          519
# 4           79
# 5            5

# %%
df.groupby(['Балл 5']).agg({'Балл 5': 'count'}) / df.shape[0] * 100
# Out:
#            Балл 5
# Балл 5
# 2       74.405772
# 3       22.028862
# 4        3.353141
# 5        0.212224

# %% [markdown]
# # Задание 8
#
# Какое процентное соотношение юношей и девушек писало данный экзамен?

# %%
#Men = df[df.loc[:, 'Пол'] == 'M'].count()
#Women = df[df.loc[:, 'Пол'] == 'Ж'].count()

df.groupby(['Пол']).agg({'Пол': 'count'}) / df.shape[0] * 100
# Out:
#            Пол
# Пол
# Ж    52.843803
# М    47.156197

# %% [markdown]
# # Задание 9
# Сколько школ принимало участие в экзамене?

# %%
df['№ школы'].nunique()
# Out:
# 17

# %% [markdown]
# # Задание 10
#
# Сколько всего заданий с кратким ответом? С развернутым ответом?

# %%
ShortAns = df.loc[0, 'Задания с кратким ответом']
len(ShortAns)
# Out:
# 12

# %%
LongAns = df.loc[0, 'Задания с развёрнутым ответом']
len(LongAns) // 4
# Out:
# 7

# %% [markdown]
# # Задание 11
#
# Пусть задания с кратким ответом будут задания типа В. Соответственно всего по экзамену вопросов класса В: В
# , ... Вк
#  Посчитайте процент выполненных и невыполненных заданий по каждому вопросу класса В.

# %%
df
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5
# ...                            ...           ...             ...   ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96
#
#       Минимальный балл  Балл 5
# 0                   27       2
# 1                   27       2
# 2                   27       2
# 3                   27       2
# 4                   27       2
# ...                ...     ...
# 2351                27       5
# 2352                27       5
# 2353                27       5
# 2354                27       5
# 2355                27       5
#
# [2356 rows x 12 columns]

# %%
for i, _ in df.iterrows():
  ShortAns = df.loc[i, 'Задания с кратким ответом']
  for j in range (len(ShortAns)):
    df.loc[i, f'B{j+1}'] = ShortAns[j]

df
# Out:
#          №  № школы Класс Пол  Номер варианта Задания с кратким ответом  \
# 0        1      124    11   Ж             341              ------+-----
# 1        2      128    11   Ж             345              -+----------
# 2        3      132    11   Ж             340              -+----------
# 3        4      134    11   Ж             339              -+----------
# 4        5      136    11   Ж             348              --------+---
# ...    ...      ...   ...  ..             ...                       ...
# 2351  2352      136    11   М             337              ++++++++++++
# 2352  2353      136    11   М             341              ++-+++++++++
# 2353  2354      136    11   М             341              ++++++++++++
# 2354  2355      136    11   М             343              ++++++++++++
# 2355  2356      136    11   Ж             337              ++++++++++++
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  ...  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5  ...
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5  ...
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5  ...
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5  ...
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN               1     5  ...
# ...                            ...           ...             ...   ...  ...
# 2351  2(2)2(2)2(2)3(3)3(3)0(4)1(4)           NaN              25    92  ...
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN              25    92  ...
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN              27    96  ...
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96  ...
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN              27    96  ...
#
#       B3  B4 B5 B6 B7 B8 B9 B10 B11 B12
# 0      -   -  -  -  +  -  -   -   -   -
# 1      -   -  -  -  -  -  -   -   -   -
# 2      -   -  -  -  -  -  -   -   -   -
# 3      -   -  -  -  -  -  -   -   -   -
# 4      -   -  -  -  -  -  +   -   -   -
# ...   ..  .. .. .. .. .. ..  ..  ..  ..
# 2351   +   +  +  +  +  +  +   +   +   +
# 2352   -   +  +  +  +  +  +   +   +   +
# 2353   +   +  +  +  +  +  +   +   +   +
# 2354   +   +  +  +  +  +  +   +   +   +
# 2355   +   +  +  +  +  +  +   +   +   +
#
# [2356 rows x 24 columns]

# %%
cols = df.loc[:, 'B1':'B12'].columns
for col in cols:
  print(col, df.groupby([col]).agg({col: 'count'}) / df.shape[0] * 100)
# Out:
# B1           B1
# B1
# +   89.26146
# -   10.73854
# B2           B2
# B2
# +   95.33107
# -    4.66893
# B3           B3
# B3
# +   92.78438
# -    7.21562
# B4            B4
# B4
# +   91.001698
# -    8.998302
# B5            B5
# B5
# +   88.497453
# -   11.502547
# B6            B6
# B6
# +   73.174873
# -   26.825127
# B7            B7
# B7
# +   37.478778
# -   62.521222
# B8            B8
# B8
# +   47.835314
# -   52.164686
# B9            B9
# B9
# +   91.850594
# -    8.149406
# B10           B10
# B10
# +    71.47708
# -    28.52292
# B11            B11
# B11
# +    59.252971
# -    40.747029
# B12            B12
# B12
# +    46.222411
# -    53.777589

# %% [markdown]
# # Задание 12
#
# Аналогично и с типом С (ответы с развернутым ответом)

# %%
for i, _ in df.iterrows():
  LongAns = str(df.loc[i, 'Задания с развёрнутым ответом'])
  for j in range (len(LongAns)):
    df.loc[i, f'С{j+1}'] = LongAns[j]

df
# Out:
#            №  № школы Класс  Пол  Номер варианта Задания с кратким ответом  \
# 0        1.0    124.0    11    Ж           341.0              ------+-----
# 1        2.0    128.0    11    Ж           345.0              -+----------
# 2        3.0    132.0    11    Ж           340.0              -+----------
# 3        4.0    134.0    11    Ж           339.0              -+----------
# 4        5.0    136.0    11    Ж           348.0              --------+---
# ...      ...      ...   ...  ...             ...                       ...
# 2352  2353.0    136.0    11    М           341.0              ++-+++++++++
# 2353  2354.0    136.0    11    М           341.0              ++++++++++++
# 2354  2355.0    136.0    11    М           343.0              ++++++++++++
# 2355  2356.0    136.0    11    Ж           337.0              ++++++++++++
# 2356     NaN      NaN   NaN  NaN             NaN                       NaN
#
#      Задания с развёрнутым ответом  Устная часть  Первичный балл  Балл  ...  \
# 0     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN             1.0   5.0  ...
# 1     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN             1.0   5.0  ...
# 2     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN             1.0   5.0  ...
# 3     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN             1.0   5.0  ...
# 4     0(2)0(2)0(2)0(3)0(3)0(4)0(4)           NaN             1.0   5.0  ...
# ...                            ...           ...             ...   ...  ...
# 2352  2(2)2(2)1(2)2(3)2(3)4(4)1(4)           NaN            25.0  92.0  ...
# 2353  2(2)1(2)2(2)1(3)3(3)4(4)2(4)           NaN            27.0  96.0  ...
# 2354  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN            27.0  96.0  ...
# 2355  2(2)2(2)2(2)0(3)3(3)4(4)2(4)           NaN            27.0  96.0  ...
# 2356                           NaN           NaN             NaN   NaN  ...
#
#       С19  С20  С21  С22  С23  С24  С25  С26  С27  С28
# 0       3    )    0    (    4    )    0    (    4    )
# 1       3    )    0    (    4    )    0    (    4    )
# 2       3    )    0    (    4    )    0    (    4    )
# 3       3    )    0    (    4    )    0    (    4    )
# 4       3    )    0    (    4    )    0    (    4    )
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2352    3    )    4    (    4    )    1    (    4    )
# 2353    3    )    4    (    4    )    2    (    4    )
# 2354    3    )    4    (    4    )    2    (    4    )
# 2355    3    )    4    (    4    )    2    (    4    )
# 2356  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2357 rows x 97 columns]

# %%
cols = df.loc[:, 'C2':'C28'].columns
for col in cols:
  print(col, df.groupby([col]).agg({col: 'count'}) / df.shape[0] * 100)
# Out:
# C2        C2
# C2
# (   100.0
# C3        C3
# C3
# 2   100.0
# C4        C4
# C4
# )   100.0
# C5            C5
# C5
# 0   84.132372
# 1    8.400509
# 2    7.467119
# C6        C6
# C6
# (   100.0
# C7        C7
# C7
# 2   100.0
# C8        C8
# C8
# )   100.0
# C9            C9
# C9
# 0   84.429359
# 1    3.012304
# 2   12.558337
# C10        C10
# C10
# (    100.0
# C11        C11
# C11
# 2    100.0
# C12        C12
# C12
# )    100.0
# C13            C13
# C13
# 0    97.284684
# 1     2.078914
# 2     0.127280
# 3     0.509122
# C14        C14
# C14
# (    100.0
# C15        C15
# C15
# 3    100.0
# C16        C16
# C16
# )    100.0
# C17            C17
# C17
# 0    96.605855
# 1     1.994060
# 2     0.296988
# 3     1.103097
# C18        C18
# C18
# (    100.0
# C19        C19
# C19
# 3    100.0
# C20        C20
# C20
# )    100.0
# C21            C21
# C21
# 0    98.896903
# 1     0.551549
# 2     0.084854
# 3     0.084854
# 4     0.381841
# C22        C22
# C22
# (    100.0
# C23        C23
# C23
# 4    100.0
# C24        C24
# C24
# )    100.0
# C25            C25
# C25
# 0    96.605855
# 1     2.460755
# 2     0.890963
# 4     0.042427
# C26        C26
# C26
# (    100.0
# C27        C27
# C27
# 4    100.0
# C28        C28
# C28
# )    100.0
